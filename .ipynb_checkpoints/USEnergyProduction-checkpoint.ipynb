# %%
import requests
import json

api_key = "4a60fcfe3a762ea4e4d9276f8944aa76"

# %%
#U.S. Crude Oil Production, Annual
url = "http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.COPRPUS.A"

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
response = requests.get(url).json()

# %%
print(json.dumps(response, indent=2, sort_keys=True))
# Out:
# {
#   "request": {
#     "command": "series",
#     "series_id": "STEO.COPRPUS.A"
#   },
#   "series": [
#     {
#       "copyright": "None",
#       "data": [
#         [
#           "2020",
#           13.201070874
#         ],
#         [
#           "2019",
#           12.410303835
#         ],
#         [
#           "2018",
#           10.956129291
#         ],
#         [
#           "2017",
#           9.351714589
#         ],
#         [
#           "2016",
#           8.8306689481
#         ],
#         [
#           "2015",
#           9.4306517096
#         ],
#         [
#           "2014",
#           8.7585999452
#         ],
#         [
#           "2013",
#           7.4669328575
#         ],
#         [
#           "2012",
#           6.5015147541
#         ],
#         [
#           "2011",
#           5.6542695288
#         ],
#         [
#           "2010",
#           5.4776768329
#         ],
#         [
#           "2009",
#           5.3490960849
#         ],
#         [
#           "2008",
#           4.999670847
#         ],
#         [
#           "2007",
#           5.0739002
#         ],
#         [
#           "2006",
#           5.0858637288
#         ],
#         [
#           "2005",
#           5.1838220384
#         ],
#         [
#           "2004",
#           5.4409673825
#         ],
#         [
#           "2003",
#           5.6492997452
#         ],
#         [
#           "2002",
#           5.7440772904
#         ],
#         [
#           "2001",
#           5.8014010329
#         ],
#         [
#           "2000",
#           5.8216030164
#         ],
#         [
#           "1999",
#           5.8814565836
#         ],
#         [
#           "1998",
#           6.2518339699
#         ],
#         [
#           "1997",
#           6.4515922356
#         ],
#         [
#           "1996",
#           6.4645263634
#         ],
#         [
#           "1995",
#           6.5596395041
#         ],
#         [
#           "1994",
#           6.6615790712
#         ],
#         [
#           "1993",
#           6.8466649178
#         ],
#         [
#           "1992",
#           7.1711245246
#         ],
#         [
#           "1991",
#           7.4165451014
#         ],
#         [
#           "1990",
#           7.3553073562
#         ]
#       ],
#       "description": "Includes lease condensate.",
#       "end": "2020",
#       "f": "A",
#       "geography": "USA",
#       "lastHistoricalPeriod": "2018",
#       "name": "U.S. Crude Oil Production, Annual",
#       "series_id": "STEO.COPRPUS.A",
#       "source": "U.S. Energy Information Administration (EIA) - Short Term Energy Outlook",
#       "start": "1990",
#       "units": "million barrels per day",
#       "updated": "2019-02-12T12:01:11-0500"
#     }
#   ]
# }
