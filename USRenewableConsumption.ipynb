# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from config import api_key

# api_key = "4a60fcfe3a762ea4e4d9276f8944aa76"

# %%
# Electric Power Sector Conventional Hydroelectric Net Summer Capacity, Annual
hydroelectric_url = "http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.HVEPCAP_US.A"

# %%
print(requests.get(hydroelectric_url))
# Out:
# <Response [200]>

# %%
response = requests.get(hydroelectric_url).json()

# %%
# print(json.dumps(response, indent=2, sort_keys=True))

# %%
# Create lists to determine x and y axis for graphs
years = []
hydroelectric_consumption = []

# Loop through Hydroelectric data API to call data being measured
for x in response["series"][0]["data"]:
    years.append(x[0])
    hydroelectric_consumption.append(x[1])
    
#values = response["series"][0]["data"][1]
years  = years[::-1]
hydroelectric = hydroelectric_consumption[::-1]

# %%
# determine year to year percentage change for energy production both fossil fuels and renewables to see if the pace of energy production has changed for either. 
# look at how energy production affects prices. 
# *Bonus: Analyze total U.S. population over the same period of time.
# Compare all of our findings together.

# %%
# Total Petroleum and Other Liquids Product Supplied, Annual
plt.figure(figsize=(20,10))

# Create a visual for the data
plt.scatter(years, hydroelectric, color="red", edgecolors="black")
plt.plot(years, hydroelectric, linewidth=1.75, color="red")
plt.title("Electric Power Sector Conventional Hydroelectric Net Summer Capacity, Annual")
plt.ylabel("MegaWatts")
plt.xlabel("Years")
plt.grid(True)

plt.show()

# %%
# Electric Power Sector Geothermal Net Summer Capacity, Annual
geothermal_url = "http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.GEEPCAP_US.A"

# %%
print(requests.get(geothermal_url))
# Out:
# <Response [200]>

# %%
response = requests.get(geothermal_url).json()

# %%
# print(json.dumps(response, indent=2, sort_keys=True))

# %%
# US Electric Power Sector Geothermal Net Summer Capacity, Annual
# Create lists to determine x and y axis for graphs
years = []
geothermal_consumption = []

# Loop through Geothermal API to call data being measured
for x in response["series"][0]["data"]:
    years.append(x[0])
    geothermal_consumption.append(x[1])
    
#values = response["series"][0]["data"][1]
years  = years[::-1]
geothermal = geothermal_consumption[::-1]

# %%
# Set the size of the figure to fit 20 years of data
plt.figure(figsize=(20,10))
# Create a visual for the data
plt.scatter(years, geothermal, color="green", edgecolors="black")
plt.plot(years, geothermal, color="green", linewidth=1.75)
plt.title("US Electric Power Sector Geothermal Net Summer Capacity, Annual")
plt.ylabel("MegaWatts")
plt.xlabel("Years")
plt.grid(True)

plt.show()

# %%
# Electric Power Sector Large-Scale Solar Net Summer Capacity, Annual
solar_url = "http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.SOEPCAPX_US.A"

# %%
print(requests.get(solar_url))
# Out:
# <Response [200]>

# %%
response = requests.get(solar_url).json()

# %%
# print(json.dumps(response, indent=2, sort_keys=True))

# %%
# Electric Power Sector Large-Scale Solar Net Summer Capacity, Annual
# Create lists to determine x and y axis for graphs
years = []
solar_consumption = []

# Loop through Solar API to call data being measured
for x in response["series"][0]["data"]:
    years.append(x[0])
    solar_consumption.append(x[1])
    
#values = response["series"][0]["data"][1]
years  = years[::-1]
solar = solar_consumption[::-1]

# %%
# Electric Power Sector Large-Scale Solar Net Summer Capacity, Annual
plt.figure(figsize=(20,10))
# # Create a visual for the data
plt.scatter(years, solar, color="orange", edgecolors="black")
plt.plot(years, solar, color="orange")
plt.title("US Solar Net Summer Capacity, Annual")
plt.ylabel("MegaWatts")
plt.xlabel("Years")
plt.grid(True)

plt.show()

# %%
# Electric Power Sector Large-Scale Wind Net Summer Capacity, Annual
wind_url = "http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.WNEPCAPX_US.A"

# %%
print(requests.get(wind_url))
# Out:
# <Response [200]>

# %%
response = requests.get(wind_url).json()

# %%
# print(json.dumps(response, indent=2, sort_keys=True))

# %%
# Electric Power Sector Large-Scale Solar Net Summer Capacity, Annual
# Create lists to determine x and y axis for graphs
years = []
wind_consumption = []

# Loop through Solar API to call data being measured
for x in response["series"][0]["data"]:
    years.append(x[0])
    wind_consumption.append(x[1])
    
#values = response["series"][0]["data"][1]
years  = years[::-1]
wind = wind_consumption[::-1]

# %%
# Electric Power Sector Wind Net Summer Capacity, Annual
plt.figure(figsize=(20,10))
# Create a visual for the data
plt.scatter(years, wind, edgecolors="black")
plt.plot(years,wind, color = "blue")
plt.title("US Wind Net Summer Capacity, Annual")
plt.ylabel("MegaWatts")
plt.xlabel("Years")
plt.grid(True)

plt.show()

# %%
renewable_urls = []
renewable_consumption = []
renewable_years = []
i = 0

renewable_urls.append("http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.HVTCBUS.A")
renewable_urls.append("http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.GETCBUS.A")
renewable_urls.append("http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.SOTCBUS.A")
renewable_urls.append("http://api.eia.gov/series/?api_key=" + api_key + "&series_id=STEO.WNTCBUS.A")

for renewables in renewable_urls:
    renewable_response = requests.get(renewables).json()
    renewable_consumption.append([])
    renewable_years.append([])
    for response in renewable_response["series"][0]["data"]:
        renewable_years[i].append(response[0])
    renewable_consumption[i] = renewable_consumption[i][::-1]
    renewable_years[i] = renewable_years[i][::-1]
    i += 1

# %%
# US Renewable Energy Consumption
plt.figure(figsize=(20,10))

# # Create a visual for the data
plt.plot(renewable_years[0], renewable_consumption[3], label="Hydroelectric", color="red", linewidth=2.0)
plt.plot(renewable_years[0], renewable_consumption[2], label="Geothermal", color ="green", linewidth=2.0)
plt.plot(renewable_years[0], renewable_consumption[1], label="Solar", color="orange", linewidth=2.0)
plt.plot(renewable_years[0], renewable_consumption[0], label="Wind", color="blue", linewidth=2.0)
plt.title("US Renewable Energy Consumption, Annual", fontsize="xx-large")
plt.ylabel("MegaWatts", fontsize="large")
plt.xlabel("Years", fontsize="large")
plt.legend(loc='center left', frameon=True, fancybox=True, fontsize="x-large")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-9e756c8539aa> in <module>
#       3
#       4 # # Create a visual for the data
# ----> 5 plt.plot(renewable_years[0], renewable_consumption[3], label="Hydroelectric", color="red", linewidth=2.0)
#       6 plt.plot(renewable_years[0], renewable_consumption[2], label="Geothermal", color ="green", linewidth=2.0)
#       7 plt.plot(renewable_years[0], renewable_consumption[1], label="Solar", color="orange", linewidth=2.0)
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~\anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (31,) and (0,)

# %%
# # Create Renewable Consumption DataFrame
renewable_consumption_df = pd.DataFrame({
    'Years': years[0],
    'Wind': renewable_consumption[0],
    'Solar': renewable_consumption[1],
    'Geothermal': renewable_consumption[2],
    'Hydroelectric': renewable_consumption[3]
})

renewable_consumption_df
#     'Wind Power' : [113651.5, 105249.7, 94657, 87488.4, 81198,72486.3, 64155.6, 59922.5, 59036.3, 45647, 39121.4, 34294.6, 24651.3, 16515.1, 11350.75, 8719.17, 6463.7, 6001.79, 4416.64, 3893.64]}),

# renewable_consumption_df

# %%
# Create Renewable Consumption DataFrame
# renewable_consumption_df = pd.DataFrame({
#     'renewable_years' : years}, "MegaWatts": geothermal_consumption
#     'Hydro Electric' : renewable_consumption[3],    
#     'Wind Power' : renewable_consumption[113651.5, 105249.7, 94657, 87488.4, 81198,72486.3, 64155.6, 59922.5, 59036.3, 45647, 39121.4, 34294.6, 24651.3, 16515.1, 11350.75, 8719.17, 6463.7, 6001.79, 4416.64, 3893.64]
# ],
#     'Geo Thermal' : renewable_consumption[2],
#     'Solar Power' : renewable_consumption[1]
# })

113651.5, 105249.7, 94657, 87488.4, 81198,72486.3, 64155.6, 59922.5, 59036.3, 45647, 39121.4, 34294.6, 24651.3, 16515.1, 11350.75, 8719.17, 6463.7, 6001.79, 4416.64, 3893.64]

renewable_consumption_df.head()

renewable_consumption_df = renewable_consumption_df.set_index('renewable_years')

ax = renewable_consumption_df.plot(kind='bar', stacked=True, figsize=(20,10), title = 'US Renewable Energy Consumption')

ax.set_title("US Renewable Energy Consumption, Annual")
ax.set_ylabel("Mega Watts")
ax.set_xlabel("Years")
