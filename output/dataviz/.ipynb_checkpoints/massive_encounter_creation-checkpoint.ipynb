# %%
import random
import pandas as pd
import numpy as np
import csv

# %%
monsters = []
attack_list = []
damage_list = []
health_list = []
strength_list = []
dex_list = []
intelligence_list = []
con_list = []
wis_list = []
cha_list = []
combat_condition_list = []
monster_file = "output_data/encounter.csv"

# %%
#set up monsters
# repeat module for another set of monsters or a single monster
moar = str("yes")
while moar == str("yes"):
    name = str(input("monster name: "))    
    count =int(float(input("How many mobs are there: ")))
    attack = int(float(input("enter attack modifier: ")))
    damage = int(float(input("enter damage modifier: ")))
    health = int(float(input("enter their total health: ")))
    strength = int(float(input("enter their strength modifier: ")))
    dex = int(float(input("enter their dex modifier: ")))
    intelligence = int(float(input("enter their intelligence modifier: ")))
    wis = int(float(input("enter their wis modifier: ")))
    con = int(float(input("enter their con modifier: ")))
    cha = int(float(input("enter their cha modifier: ")))
    combat_condition = str("normal")
    while count > 0:
        Monster_ID = name + str(count)
        monsters.append(Monster_ID)
        attack_list.append(attack)
        damage_list.append(damage)
        health_list.append(health)
        cha_list.append(cha)
        wis_list.append(wis)
        con_list.append(con)
        strength_list.append(strength)
        intelligence_list.append(intelligence)
        dex_list.append(dex)
        combat_condition_list.append(combat_condition)
        count -= 1
    moar = str(input("Are there any more monster groups (enter yes or no)"))
# Out:
# monster name: orc
# How many mobs are there: 43
# enter attack modifier: 4
# enter damage modifier: 3
# enter their total health: 5
# enter their strength modifier: 3
# enter their dex modifier: 4
# enter their intelligence modifier: 2
# enter their wis modifier: 3
# enter their con modifier: 4
# enter their cha modifier: 5
# Are there any more monster groups (enter yes or no)no

# %%
Monster_dictionary = {"monster_name": monsters, "attack mod": attack_list, "damage mod": damage_list, "monster health": health_list, "str mod": strength_list, "dex mod": dex_list, "int mod": intelligence_list, "con mod": con_list, "cha mod": cha_list, "wis mod": wis_list, "combat condition": combat_condition}
Monster_rolls = pd.DataFrame(Monster_dictionary, index=monsters)
Monster_rolls
Monster_rolls.to_csv("output_data/encounter.csv", index=False)

# %%
len(monsters)
# Out:
# 34

# %%
# Rolls
attack_roll = []
test = []
mob = len(monsters)
for x in range(mob):
    rollD20_1 = random.randint(1,21) 
    rollD20_2 = 
    attack_roll.append(rollD20)
attack_total = np.add(attack_roll, attack_list)

# %%
#Area of effect Damage

# %%
Monster_dictionary = {"monster_name": monsters, "attack roll": attack_total}
Monster_rolls = pd.DataFrame(Monster_dictionary, index=monsters)
Monster_rolls
# Out:
#       monster_name  attack roll
# orc34        orc34            7
# orc33        orc33           10
# orc32        orc32           20
# orc31        orc31           24
# orc30        orc30           11
# orc29        orc29           23
# orc28        orc28           16
# orc27        orc27           13
# orc26        orc26           17
# orc25        orc25            5
# orc24        orc24           14
# orc23        orc23            9
# orc22        orc22           18
# orc21        orc21           12
# orc20        orc20           12
# orc19        orc19           24
# orc18        orc18           13
# orc17        orc17           22
# orc16        orc16           14
# orc15        orc15           23
# orc14        orc14            5
# orc13        orc13            6
# orc12        orc12           15
# orc11        orc11           21
# orc10        orc10           15
# orc9          orc9           15
# orc8          orc8           12
# orc7          orc7           25
# orc6          orc6           11
# orc5          orc5           19
# orc4          orc4            9
# orc3          orc3           17
# orc2          orc2           11
# orc1          orc1           13

# %%
# Drop an observation or row
Monster_rolls.drop(["orc2"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-deeea4048af1> in <module>
#       1 # Drop an observation or row
# ----> 2 Monster_rolls.drop(["orc2"])
#
# C:\Users\jhartung\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Users\jhartung\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\Users\jhartung\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# C:\Users\jhartung\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['orc2'] not found in axis"
